# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt

# %%
x = np.linspace(1,50,10)
y = x**2
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x = np.linspace(1,50,10)
y = np.sqrt(x)
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x = np.linspace(1,50,10)
y = np.sin(x)
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x = np.linspace(1,50,10)
y = np.cos(x)
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x = np.linspace(1,50,10)
y = np.tan(x)
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')
