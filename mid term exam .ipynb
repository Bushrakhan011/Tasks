# %% [markdown]
# # Numerical Methods Mid term Paper
#
# ## Total Marks : 25

# %% [markdown]
# # Question #1
#
# Convert the following algorithms into python by using functions and then solve the following problem
#
# Find the roots of the following equation
#
# $2x^2 - 5x + 3 = 0$  analytical roots are $x = 1.5,1$

# %% [markdown]
# ## Algorithm 1 (Secant Method)
#
# 1. Input two values for $x_1$ and $x_2$
# 2. Calculate $x_{new} = x_2 - \frac{x_2-x_1}{f(x_2)-f(x_1)}f(x_2)$
# 3. If $|x_{new} - x_2| < tolerance$ , output $x_{new}$ the root and stop
# 4. If number of iterations reaches the maximum, stop.
# 5. Else let $x_1=x_2$ and $x_2=x_{new}$
# 6. Repeat the steps from 2

# %% [markdown]
# ## Algorithm 2 (Newton's Methd)
#
#
# 1. Find $f'(x)$ and define newton's raphson equation
# 2. Guess an initial value of x for the first iteration
# 3. substitute x in the NR equation and calculate $x^*$
# 4. if $|x^*-x|<tolerance$, stop iterations and output the root: $x^*$
# 5. if the number of interations reaches an assumed maximum, stop.
# 6. else let $x=x^*$ and repeat the steps from 3 until a condition in 4 or 5 is satisfied.

# %%
# Out:
#   File "C:\Users\ASUSF5~1\AppData\Local\Temp/ipykernel_7448/1543529479.py", line 2
#     from math library
#               ^
# SyntaxError: invalid syntax

# %%
from math import sin
def secant(fn,x1,x2,tol,maxiter):
    for i in range(maxiter):
        n = x2-x1
        d = (fn(x2)-fn(x1))
        xnew = x2 - ( ( n/d )*fn(x2) )
        if abs(xnew-x2) < tol:   
            print("The root is : ",xnew)
            break  
            
            print('warning: Maximum number of iterations is reached')

        else:
            x1 = x2 
            x2 = xnew 

f = lambda x: 2*x**2 - 5*x + 3 
x1 = float(input('enter x1: ')) 
x2 = float(input('enter x2: '))
secant(f,x1,x2,1.0e-6,100)
# Out:
# enter x1: 2
# enter x2: 1.5
# The root is :  1.5

# %%
from math import sin,cos
def newton(fn,dfn,x,tol,maxiter): 
    for i in range(maxiter):   
        xnew = x - fn(x)/dfn(x) 
        if abs(xnew-x)<tol:   
            print("The root is : ",xnew)
            break 
        elif i == maxiter:
            print('warning: Maximum number of iterations is reached')
            break
        x = xnew 

y = lambda x: 2*x**2 - 5*x + 3
dy = lambda x : 4*x-5      

newton(y, dy,1, 0.0001, 100)
# Out:
# The root is :  1.0

# %%
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2
x = 0.1
h = 0.1
df1 = 0.09405
df2 = -0.118
print("\t f'(x)\t\t err\t\t f''(x)\t\t err")
dff1 = (f(x+h)-f(x))/h
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
print("FFD\t% .8f\t% .8f\t% .8f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2
print("BFD\t% .8f\t% .8f\t% .8f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
print("CFD\t% .8f\t% .8f\t% .8f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
# Out:
# 	 f'(x)		 err		 f''(x)		 err
# FFD	 0.08631000	-0.00774000	-0.22200000	-0.104000
# BFD	 0.09801000	 0.00396000	 0.00000000	 0.118000
# CFD	 0.09216000	-0.00189000	-0.11700000	 0.001000

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.1
x = np.linspace(-1,1,100)
#backward differnce
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2

plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.1
x = np.linspace(-1,1,100)
#forward difference
dff1 = (f(x+h)-f(x))/h 
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
x = np.linspace(-1,1,100)
#backward differnce
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2

plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.001
x = np.linspace(-1,3.5,100)
#backward differnce
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2

plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
x = np.linspace(-1,1,100)
#forward difference
dff1 = (f(x+h)-f(x))/h 
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.001
x = np.linspace(-1,1,100)
#forward difference
dff1 = (f(x+h)-f(x))/h 
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt

x = np.linspace(7,-5,10)
y = 2*x**2 - 5*x + 3
dy = 4*x -5
plt.plot(x,y,dy)
plt.xlabel('X-axis',fontsize=22)
plt.ylabel('Y-axis',fontsize=22)
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.001
x = np.linspace(-3,3,100)
#Central difference
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
x = np.linspace(-2,2,100)
#Central difference
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.1
x = np.linspace(-1.5,1.5,100)
#Central difference
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()
